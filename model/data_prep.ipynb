# %% [markdown]
# Select 200 distinct rows based on poster_id from poster_got_50w.csv and save the result in poster_test_200.csv

# %%
import pandas as pd

# Define the file path
file_path = '/home/disk1/red_disk1/Multimodal_MKT/test/sample_310.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Select 300 distinct poster_id
distinct_poster_ids = df['poster_id'].drop_duplicates().head(300)

# Filter the DataFrame to include only rows with the selected poster_id
filtered_rows = df[df['poster_id'].isin(distinct_poster_ids)]

# Save the new DataFrame to a CSV file
output_path = '/home/disk1/red_disk1/test/poster_test_300.csv'
filtered_rows.to_csv(output_path, index=False)

print(f"New CSV file with rows corresponding to 300 distinct poster_id saved as 'poster_test_300.csv'")
# Out:
# New CSV file with rows corresponding to 300 distinct poster_id saved as 'poster_test_50.csv'

# %% [markdown]
# #### Keep fashion posts only
#
# 1. Filter rows containing fashion-related keywords in 'post_title' or 'post_content'
# 2. Remove posts with no post_date or post_like or post_collect or post_comments
# 3. Set time range from 2023-06-01 to 2024-05-31 to ensure exactly one year

# %%
import pandas as pd
import re

# Define the path to the CSV file
file_path = '/home/disk1/red_disk1/Multimodal_MKT/test/sample_310.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Convert 'post_date' to datetime format
df['post_date'] = pd.to_datetime(df['post_date'], errors='coerce')

# Define the date range
start_date = '2023-06-01'
end_date = '2024-05-31'

# Filter rows based on the date range
df = df[(df['post_date'] >= start_date) & (df['post_date'] <= end_date)]

# Define fashion-related keywords
fashion_keywords = [
    "时尚", "穿搭", "搭配", "潮流", "服装", "造型", "衣服", "新品", "裙子", "裤子", "连衣裙", 
    "上衣", "衬衫", "外套", "牛仔裤", "毛衣", "包包", "鞋子", "首饰", "帽子", "眼镜", "简约", 
    "休闲", "正式", "甜美", "酷", "时髦", "复古", "韩系", "日系", "轻奢", "#OOTD", "#Ootd", 
    "#ootd", "#时尚达人", "#穿搭指南", "#今日穿搭", "#潮流搭配", "#时尚博主", "#新品推荐", 
    "#街拍", "#每日穿搭", "#名牌", "夏装", "冬装", "春装", "秋装", "节日", "婚礼"
]

# Create a regex pattern for the fashion keywords
pattern = re.compile('|'.join(fashion_keywords), re.IGNORECASE)

# Filter rows containing fashion-related keywords in 'post_title' or 'post_content'
df_fashion = df[df['post_title'].str.contains(pattern, na=False) | df['post_content'].str.contains(pattern, na=False)]

# Remove rows with missing information in the specified columns
df_fashion_cleaned = df_fashion.dropna(subset=['post_date', 'post_like', 'post_collect', 'post_comments'])

# Count the number of distinct poster_id and post_id
num_distinct_poster_id = df_fashion_cleaned['poster_id'].nunique()
num_distinct_post_id = df_fashion_cleaned['post_id'].nunique()

# Print the counts
print(f"There are {num_distinct_poster_id} distinct poster_id in the filtered data.")
print(f"There are {num_distinct_post_id} distinct post_id in the filtered data.")

# Save the updated DataFrame to a new CSV file
output_path = '/home/disk1/red_disk1/Multimodal_MKT/test/poster_test_fashion.csv'
df_fashion_cleaned.to_csv(output_path, index=False)

print("Filtered data has been saved to", output_path)
# Out:
# There are 137 distinct poster_id in the filtered data.
# There are 5482 distinct post_id in the filtered data.
# Filtered data has been saved to /home/disk1/red_disk1/Multimodal_MKT/test/poster_test_fashion.csv

# %% [markdown]
# Select the data from the all_data folder based on poster_id and post_id in poster_test_fashion.csv

# %%
import pandas as pd
import os
import shutil

# Define the file paths
csv_file_path = '/home/disk1/red_disk1/Multimodal_MKT/test/poster_test_fashion.csv'
all_data_folder = '/home/disk1/red_disk1/all_data'
output_folder = '/home/disk1/red_disk1/Multimodal_MKT/test/data'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load the CSV file
df = pd.read_csv(csv_file_path)

# Iterate over each unique combination of poster_id and post_id
for _, row in df.iterrows():
    poster_id = str(row['poster_id'])
    post_id = str(row['post_id'])
    
    # Define the source folder path
    source_post_folder = os.path.join(all_data_folder, poster_id, post_id)
    
    # Define the destination folder path
    dest_post_folder = os.path.join(output_folder, poster_id, post_id)
    
    # Check if the source folder exists
    if os.path.exists(source_post_folder):
        # Copy the entire post_id folder to the destination
        shutil.copytree(source_post_folder, dest_post_folder, dirs_exist_ok=True)
        print(f"Copied data for poster_id {poster_id}, post_id {post_id}")
    else:
        print(f"Source folder for poster_id {poster_id}, post_id {post_id} does not exist")

print("Data selection completed.")
# Out:
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 665985df00000000150103e9
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 66585111000000001303f660
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 6657236f000000000c0195f0
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 66568683000000001303dfbf
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 6653eb88000000001501251c
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 6652aac10000000015008a16
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 6652948d000000000c01a4f7
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 6651920f000000001303c673
# Copied data for poster_id 596e2a6c6a6a6906aa20764a, post_id 665140e7000000000f00c620
# Copied data for poster_id 6191e8000000000010007643, post_id 65cf8cac0000000007007b5c
# Copied data for poster_id 5dff75100000000001001bb3, post_id 661f89140000000003020f2c
# Copied data for poster_id 5dff75100000000001001bb3, post_id 65f94da50000000014007178
# Copied data for poster_id 5c5a3a28000000001103442c, post_id 65d41b39000000000b00fec9
# Copied data for poster_id 5c5a3a28000000001103442c, post_id 65d56c75000000000b017253
# Copied data for poster_id 5c5a3a28000000001103442c, post_id 6659417a00000000150139d0
# Copied data for poster_id 5c5a3a28000000001103442c, post_id 665808a4000000001501342a
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6618b093000000001a01012d
# Copied data for poster_id 637170c2000000001f01ad59, post_id 64f148cc000000001f004f29
# Copied data for poster_id 637170c2000000001f01ad59, post_id 665811a80000000016013ae1
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6658110a00000000050077da
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66567f900000000016011e11
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66567f4100000000160119cd
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66555484000000000500541e
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6655367000000000140195e6
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664ebb0900000000140191a8
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664ea66a00000000140198a0
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664d4623000000001401a205
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664d45c00000000016012b0f
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664c55d6000000000500484f
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664c551000000000160138e2
# Copied data for poster_id 637170c2000000001f01ad59, post_id 664aca900000000005007a3c
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6645a487000000001e033288
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66444a4c000000001e030150
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6642d390000000001e0381b5
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6642ba55000000001e033959
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6642b9cf000000001e034f25
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6641d0ae000000001e033b89
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66418e44000000001e0383ac
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6638415b000000001e039439
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6638407c000000001e0315ce
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6630a580000000001e0346d5
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662f0a6f00000000010339d5
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662f01d30000000004018a0c
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662b7616000000000103112b
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662a1248000000000401bee4
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6629b9560000000001031338
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66286b480000000001033d8d
# Copied data for poster_id 637170c2000000001f01ad59, post_id 66286adb0000000001005c95
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662605dc0000000001030240
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662605360000000001005154
# Copied data for poster_id 637170c2000000001f01ad59, post_id 662604dc0000000001004a65
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6621cd120000000001032973
# Copied data for poster_id 637170c2000000001f01ad59, post_id 661f5ad3000000000401890f
# Copied data for poster_id 637170c2000000001f01ad59, post_id 661e0ff9000000000401810d
# Copied data for poster_id 637170c2000000001f01ad59, post_id 661cc112000000001a01203e
# Copied data for poster_id 637170c2000000001f01ad59, post_id 661b2a4a000000001a011721
# Copied data for poster_id 637170c2000000001f01ad59, post_id 661b2a14000000001a017f3a
# Copied data for poster_id 637170c2000000001f01ad59, post_id 661601d5000000001a010107
# Copied data for poster_id 637170c2000000001f01ad59, post_id 6616016b000000001a015e6d
# Copied data for poster_id 5d39486b00000000110269b6, post_id 654eeeb8000000001b03548d
# Copied data for poster_id 5d39486b00000000110269b6, post_id 651ad358000000001e02c1ba
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6576d77e0000000038036bef
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65577f38000000001f02e581
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 655604c2000000001701e6f7
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 655211aa000000003103ccfb
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6550c1850000000032005217
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6576d77e0000000038036bef
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 655604c2000000001701e6f7
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 655211aa000000003103ccfb
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6550c1850000000032005217
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 654e1c17000000001b00e480
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 654cceed000000003202a0ee
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 654b7d22000000003200a3c0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65463846000000001e02aaea
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 654a0c2e000000001f00582e
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6544e3cf000000001f03cd4d
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65439e46000000001e03cd3f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65423f4e000000001f03cfa2
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6540f1f9000000001e031b11
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 653fa7b3000000001f006d85
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 653cfc450000000020002c0c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 653baa8a000000001e033328
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 653a56ad000000001e029f95
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6536633b000000001f036cf0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65351440000000001f03f704
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6533bfc8000000001e02d323
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6532753c000000001e03f0c4
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6531206b000000001d015f6c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652fcb38000000001f03440d
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652e88b5000000001d016a7f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652d270c000000001e032d80
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652bd5a1000000001f03a31c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652a85c0000000001f0374b8
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652938b2000000001e00fd2c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6527f1a4000000001e023290
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65268f74000000001e033c44
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6523ed05000000001e022c26
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 652163b0000000001e02fd6f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651ffa77000000001e00f131
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651eaa7a000000001e022166
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651d64b9000000001e00e37f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651c063b000000001d017e64
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651ab3a1000000001e023e56
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651964460000000020002de0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6516c106000000001f006b2c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6515716a000000001f03f8d8
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65118338000000001d015cfb
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 651024e9000000001e02037b
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 650edde0000000001e0284d0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 650d8659000000001f004328
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 650c412c0000000020002fbb
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 650adcef0000000020000884
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6509a8e9000000001e0308dc
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65086377000000001e02f8d3
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6506ea34000000001e00f411
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6503e828000000001f03c7bd
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 65005760000000001f0373dc
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64fb3eed000000001e00c91e
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64f9ea0b000000001d0158b4
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64f88b56000000001e02fe03
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64f7468a000000001e03f395
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64f5e06e000000001f03de8a
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64f31a83000000001e0331bb
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ee15c000000000200034c3
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ec73af000000000103ca8f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64eb6567000000000103c5b8
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64e9dcc2000000000800c9a6
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64e877c8000000001700f745
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64e7202a000000000a01909f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64e488bd000000000c037679
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64e35ccc000000001700f842
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64e1f141000000001701b126
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64dcca040000000003020202
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64db4dbf00000000120187b2
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d9f3db00000000170192e0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d8aa69000000000301e4a0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d74d7b000000000301cf42
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d614e9000000000103df93
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d4de5b000000001700cfed
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d3b6f3000000000b0292cf
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d20bcf000000001701b3f6
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64d0c661000000001201cdea
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64cf699c000000000c036496
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ce23ba000000001201f379
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ccc3dc000000000800ff9c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64cb70490000000017018975
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ca2687000000000b02b2c9
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64c901f6000000001701920b
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64c7817e0000000010032458
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64c62c1e0000000017018bb4
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64c4d97d000000001201f987
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64c24c80000000001701bb27
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64bf990e000000000103f172
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64be6465000000000a01a68d
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ba4d23000000000c035a67
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64bd0868000000000103d2d1
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64bbaa98000000001700fda6
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64b8f8ae0000000012018cb7
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64b7a731000000003401757e
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64b65df5000000002b03a542
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64b3d86c000000002301e1f8
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64b26a0f00000000340151b1
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64b118c1000000002f0284b7
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64afc096000000002f02573d
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ae7030000000003100bc0c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64ad1d77000000002f0266b4
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64abce03000000002f026310
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64aa7a6a0000000012012ab5
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a924b9000000001c018206
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a7d791000000003102d002
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a6763f000000001c00ecf8
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a555020000000015032a69
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a3e28a0000000035008723
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a2916e00000000340177f0
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64a140550000000027013881
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 649fed1c00000000070390df
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 649e9f030000000013003d23
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 649d15f9000000000800d00d
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 649955be000000001303ec63
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6498071a00000000130316ca
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6496b5610000000014025109
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6495637200000000130174cc
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64940ed8000000001300d958
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6492bc6d0000000027011268
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64916c64000000001303018a
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64901fd20000000012031612
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 648ec8ca00000000110128a7
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 648d76450000000013016ebc
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 648c26700000000014027a34
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 648ad7ac000000001303c22d
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6488305b000000001101308f
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6486defe000000002702b18c
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 64859ca6000000001203e2f1
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6482eb68000000001203d54a
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 648199120000000012032ebb
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 648049c80000000013005b86
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 647ef689000000001303ce3a
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 647da613000000000800dbf8
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 647c552a0000000027028408
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 647b027f00000000130100ad
# Copied data for poster_id 5b02ba7f6b58b73748730d90, post_id 6479b2b8000000002702b906
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 658e1df7000000000f011235
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 6588ea67000000000602b2aa
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 658689ac000000000901ce82
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 65813e90000000000901dff3
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 65217af8000000002202a13b
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 650fec09000000001302c95d
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 6507cf0800000000160330c8
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64ff20a6000000001e02ea53
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 652fdac200000000250089cd
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64fc1266000000001f03e874
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64e8be1b000000001201bb36
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64e75e97000000001701abab
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64e2f5650000000012018210
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64d86094000000001201bb75
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64d1b729000000000a01a1ea
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64cccd66000000000103fd3a
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64c5ef7a000000001201d4ae
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64c38bbf000000000103e1de
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64b89184000000000f00e441
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64af6c42000000003401530c
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64acb3c7000000002b03af77
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64a3853000000000340148df
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 6493d38a000000001303d854
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 648f17960000000012032313
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 648d95560000000007039afc
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 648950ef000000001303c6c8
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 648546bc0000000013030f28
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 64797425000000001203263d
# Copied data for poster_id 55b521dc67bc653baf1d059d, post_id 6478a2b70000000013016840
# Copied data for poster_id 63d920f00000000026005cac, post_id 656b446a0000000038022e1c
# Copied data for poster_id 63d920f00000000026005cac, post_id 6569b7530000000016007ad4
# Copied data for poster_id 63d920f00000000026005cac, post_id 655b535b000000001100f8d8
# Copied data for poster_id 63d920f00000000026005cac, post_id 653d0462000000001f0048e8
# Copied data for poster_id 63d920f00000000026005cac, post_id 6531147f000000001d016867
# Copied data for poster_id 63d920f00000000026005cac, post_id 652a577e000000001f03c5c4
# Copied data for poster_id 63d920f00000000026005cac, post_id 65196a63000000001f006b6f
# Copied data for poster_id 63d920f00000000026005cac, post_id 651551d0000000001f03fbfc
# Copied data for poster_id 63d920f00000000026005cac, post_id 65144dd70000000020000adf
# Copied data for poster_id 63d920f00000000026005cac, post_id 6512f230000000001e03c8ac
# Copied data for poster_id 63d920f00000000026005cac, post_id 64c617a1000000001700c275
# Copied data for poster_id 63d920f00000000026005cac, post_id 64a2f482000000002f028f39
# Copied data for poster_id 63d920f00000000026005cac, post_id 64970ab30000000013000030
# Copied data for poster_id 621073b60000000010006a49, post_id 66441120000000001e0189aa
# Copied data for poster_id 621073b60000000010006a49, post_id 662c5336000000001c006cd6
# Copied data for poster_id 621073b60000000010006a49, post_id 6623a742000000001c00b379
# Copied data for poster_id 621073b60000000010006a49, post_id 66233e59000000000d0304af
# Copied data for poster_id 621073b60000000010006a49, post_id 65f194fd0000000014007d5e
# Copied data for poster_id 621073b60000000010006a49, post_id 65d6b640000000000b0235a9
# Copied data for poster_id 621073b60000000010006a49, post_id 65bc62aa000000000103002c
# Copied data for poster_id 621073b60000000010006a49, post_id 65b883670000000002020a24
# Copied data for poster_id 621073b60000000010006a49, post_id 65addd190000000011007aaf
# Copied data for poster_id 621073b60000000010006a49, post_id 65a9e20300000000280292ce
# Copied data for poster_id 621073b60000000010006a49, post_id 65a879fe0000000029016fa5
# Copied data for poster_id 621073b60000000010006a49, post_id 657122dc00000000050390dc
# Copied data for poster_id 621073b60000000010006a49, post_id 6556c402000000003203583a
# Copied data for poster_id 621073b60000000010006a49, post_id 65279195000000001a0211c7
# Copied data for poster_id 621073b60000000010006a49, post_id 650ec5c90000000016033881
# Copied data for poster_id 621073b60000000010006a49, post_id 6507f9df000000001302a2d7
# Copied data for poster_id 621073b60000000010006a49, post_id 6502e0b50000000016032094
# Copied data for poster_id 621073b60000000010006a49, post_id 64fd3107000000001f007da7
# Copied data for poster_id 621073b60000000010006a49, post_id 64f9504d000000001f03e659
# Copied data for poster_id 621073b60000000010006a49, post_id 64f1d4c0000000001f03a008
# Copied data for poster_id 621073b60000000010006a49, post_id 64f1363c000000001f005eb0
# Copied data for poster_id 621073b60000000010006a49, post_id 64f04fcd000000001e02e580
# Copied data for poster_id 621073b60000000010006a49, post_id 64e69b2d000000000302118e
# Copied data for poster_id 621073b60000000010006a49, post_id 64e17285000000000301cbb1
# Copied data for poster_id 621073b60000000010006a49, post_id 64da2659000000000c036c9d
# Copied data for poster_id 621073b60000000010006a49, post_id 64cb12ef000000000c036d02
# Copied data for poster_id 621073b60000000010006a49, post_id 64b4c100000000001e01b144
# Copied data for poster_id 621073b60000000010006a49, post_id 64ade6ed000000003500b453
# Copied data for poster_id 621073b60000000010006a49, post_id 649f991d000000001300abae
# Copied data for poster_id 621073b60000000010006a49, post_id 649ec389000000001203c68a
# Copied data for poster_id 621073b60000000010006a49, post_id 649807230000000011012f9d
# Copied data for poster_id 621073b60000000010006a49, post_id 649fd9350000000027002e27
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6659235a000000000c018202
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6657b2e9000000000c019a55
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6656b6f700000000150089f0
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 665541d5000000001500b44d
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6653f85e0000000015009521
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6652c115000000000f00cbeb
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 66514124000000001500a1bd
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 66500ab9000000000f00c999
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 664d67d9000000001303d8a0
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 664ac85b000000000f00ecd9
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 664552c5000000001e02eb69
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6641bebb000000001e020a24
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 663ec24a000000001e02599e
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 662facc9000000001e025b46
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 662afee9000000000d030fb5
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6628faf1000000000d03252d
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6624bea8000000000302361c
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 661ce795000000001c008259
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6617d3a4000000000401abf4
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 66149f30000000001b00f389
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6613bd95000000000401b5ec
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 660a239a000000001b00ac9b
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6602319100000000120379d9
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6601249100000000120349e2
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65fbfa2b0000000014006c5a
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65e91834000000000303331f
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65e6705d000000000b0201f9
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65cee4f5000000000b01653a
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65cca672000000000b00ce89
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65caeac0000000000a0324bb
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65e5b12b000000000b00fccd
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65c853cb000000000c007046
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65c6c9360000000001032d52
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65c302e4000000001100d4ed
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65c1ac8400000000110019fd
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65c0b25d000000001100d5ed
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65be33ed00000000110034af
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65bb4b9a000000000a032f41
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65b9e600000000001100164e
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65b850f5000000001100468b
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65b73d0f000000001003a8ec
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65b5ce56000000001003a3b1
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65b482450000000010039ec6
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65b325770000000011013190
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65ab4143000000001100cae8
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65aa211f0000000029016f8d
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65a8edc8000000002803a0b7
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65a7b95c0000000029015c36
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65a6170e000000000f033eeb
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65a4ae2c000000000f0100a9
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 659ff218000000001200b0b8
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 659cb54f000000001101904b
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6598c1570000000010011820
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 658b9c0e0000000012002767
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65864d3a0000000005038c17
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 658252470000000009020c90
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 657eaae9000000000700b0db
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 657bf9c4000000000901ddde
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 657ad803000000000901852d
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65793fd10000000007008fab
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6578281f0000000006022e6d
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6575cdf1000000000901ee25
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6573e527000000000901c622
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 657192080000000005038901
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6563570f000000003202ddc1
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 655351af0000000033003abf
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6551a5fd0000000032038792
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 65444e64000000000403a7d9
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 6543199a000000002500bd52
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 64f6d76a000000001f03a8a4
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 64bf82a9000000000a01addc
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 64ad4ab2000000001c00e45d
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 64a8b1ee0000000015030bd2
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 64a54b4b000000002f0267c0
# Copied data for poster_id 5ba06a6fb851660001bb15d0, post_id 649d8584000000001303c0bb
# Copied data for poster_id 60e4f070000000000100599d, post_id 66590fa9000000001500b8ac
# Copied data for poster_id 60e4f070000000000100599d, post_id 66566b89000000000c01899e
# Copied data for poster_id 60e4f070000000000100599d, post_id 66551fd6000000000c01af9a
# Copied data for poster_id 60e4f070000000000100599d, post_id 6653cd920000000015009773
# Copied data for poster_id 60e4f070000000000100599d, post_id 6651ae46000000000c0182e4
# Copied data for poster_id 60e4f070000000000100599d, post_id 664fd2ac000000001303f0de
# Copied data for poster_id 60e4f070000000000100599d, post_id 664e883a00000000150125a5
# Copied data for poster_id 60e4f070000000000100599d, post_id 664d374f000000000c01b9d7
# Copied data for poster_id 60e4f070000000000100599d, post_id 664c6586000000001303cd6b
# Copied data for poster_id 60e4f070000000000100599d, post_id 664be72f00000000150115ae
# Copied data for poster_id 60e4f070000000000100599d, post_id 664a94d700000000150089f1
# Copied data for poster_id 60e4f070000000000100599d, post_id 664953ca0000000015012451
# Copied data for poster_id 60e4f070000000000100599d, post_id 6647fcf7000000000f00eb78
# Copied data for poster_id 60e4f070000000000100599d, post_id 6646a0d8000000001e022d16
# Copied data for poster_id 60e4f070000000000100599d, post_id 66454ca9000000001e01fcdc
# Copied data for poster_id 60e4f070000000000100599d, post_id 66447e03000000001e02cdc1
# Copied data for poster_id 60e4f070000000000100599d, post_id 6645cc9d000000001e01cde2
# Copied data for poster_id 60e4f070000000000100599d, post_id 6643fa0b000000001e01c4c4
# Copied data for poster_id 60e4f070000000000100599d, post_id 66433179000000001e026a6d
# Copied data for poster_id 60e4f070000000000100599d, post_id 6641df33000000001e01eebb
# Copied data for poster_id 60e4f070000000000100599d, post_id 664157af000000001e021fd1
# Copied data for poster_id 60e4f070000000000100599d, post_id 66400785000000001e01f96c
# Copied data for poster_id 60e4f070000000000100599d, post_id 663d6460000000001e02c6d1
# Copied data for poster_id 60e4f070000000000100599d, post_id 663c162a000000001e02fe15
# Copied data for poster_id 60e4f070000000000100599d, post_id 663ac27e000000001e02501e
# Copied data for poster_id 60e4f070000000000100599d, post_id 6639f892000000001e01bed2
# Copied data for poster_id 60e4f070000000000100599d, post_id 663837ee000000001e02c1b5
# Copied data for poster_id 60e4f070000000000100599d, post_id 6636dcce000000001e02fda4
# Copied data for poster_id 60e4f070000000000100599d, post_id 66360213000000001e022ce8
# Copied data for poster_id 60e4f070000000000100599d, post_id 6635a51b000000001e01b923
# Copied data for poster_id 60e4f070000000000100599d, post_id 6632d8ae000000001e01fd18
# Copied data for poster_id 60e4f070000000000100599d, post_id 66319ae5000000001e01ddc3
# Copied data for poster_id 60e4f070000000000100599d, post_id 662d9ae00000000003022239
# Copied data for poster_id 60e4f070000000000100599d, post_id 662c4b68000000001c00b2ce
# Copied data for poster_id 60e4f070000000000100599d, post_id 662af2a9000000001c008cd2
# Copied data for poster_id 60e4f070000000000100599d, post_id 66299fdd0000000003023300
# Copied data for poster_id 60e4f070000000000100599d, post_id 6628978f0000000003021b16
# Copied data for poster_id 60e4f070000000000100599d, post_id 662783dc000000001c00a3cc
# Copied data for poster_id 60e4f070000000000100599d, post_id 6626f9b4000000001c00830b
# Copied data for poster_id 60e4f070000000000100599d, post_id 6625c496000000001c006af3
# Copied data for poster_id 60e4f070000000000100599d, post_id 6624d659000000001c0080fb
# Copied data for poster_id 60e4f070000000000100599d, post_id 6624683f000000001c007c0e
# Copied data for poster_id 60e4f070000000000100599d, post_id 662305740000000003020074
# Copied data for poster_id 60e4f070000000000100599d, post_id 662234680000000003021923
# Copied data for poster_id 60e4f070000000000100599d, post_id 6621b37d000000001c00871a
# Copied data for poster_id 60e4f070000000000100599d, post_id 6620e4f1000000000d0338b4
# Copied data for poster_id 60e4f070000000000100599d, post_id 661b2416000000001b00e4f7
# Copied data for poster_id 60e4f070000000000100599d, post_id 66188010000000001b00e3c0
# Copied data for poster_id 60e4f070000000000100599d, post_id 661728ea000000001b009c28
# Copied data for poster_id 60e4f070000000000100599d, post_id 66148674000000000401ab75
# Copied data for poster_id 60e4f070000000000100599d, post_id 661358e7000000001b00d5c6
# Copied data for poster_id 60e4f070000000000100599d, post_id 6611e202000000001b0113f7
# Copied data for poster_id 60e4f070000000000100599d, post_id 66112a8b000000001b008d82
# Copied data for poster_id 60e4f070000000000100599d, post_id 6610a020000000001b00f51c
# Copied data for poster_id 60e4f070000000000100599d, post_id 660df41d000000001b0120b7
# Copied data for poster_id 60e4f070000000000100599d, post_id 660a7bca000000001b00bd2e
# Copied data for poster_id 60e4f070000000000100599d, post_id 660a0070000000001b00c9a5
# Copied data for poster_id 60e4f070000000000100599d, post_id 6608adad000000001b01009c
# Copied data for poster_id 60e4f070000000000100599d, post_id 660606010000000012037caf
# Copied data for poster_id 60e4f070000000000100599d, post_id 660361d0000000001203409f
# Copied data for poster_id 60e4f070000000000100599d, post_id 66020ebb00000000120325d8
# Copied data for poster_id 60e4f070000000000100599d, post_id 6600bf030000000014005d5d
# Copied data for poster_id 60e4f070000000000100599d, post_id 65ff6fef0000000014007a6b
# Copied data for poster_id 60e4f070000000000100599d, post_id 65fe1ba20000000013026449
# Copied data for poster_id 60e4f070000000000100599d, post_id 65fccc880000000012030a32
# Copied data for poster_id 60e4f070000000000100599d, post_id 65fb7d7c0000000014004ac6
# Copied data for poster_id 60e4f070000000000100599d, post_id 65fa2a310000000012032bb5
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f8d8820000000012033afc
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f7895b0000000012032cef
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f63c3d000000001400765b
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f4e25d0000000012031fb2
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f3923900000000120365b6
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f2c0790000000014006122
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f23e5400000000120328a2
# Copied data for poster_id 60e4f070000000000100599d, post_id 65f141ac0000000012035978
# Copied data for poster_id 60e4f070000000000100599d, post_id 65ed0bcd000000000b0224a6
# Copied data for poster_id 60e4f070000000000100599d, post_id 65eade1500000000030324f4
# Copied data for poster_id 60e4f070000000000100599d, post_id 65e902ed000000000600fedf
# Copied data for poster_id 60e4f070000000000100599d, post_id 65e83225000000000b00d842
# Copied data for poster_id 60e4f070000000000100599d, post_id 65e50f17000000000b019cd4
# Copied data for poster_id 60e4f070000000000100599d, post_id 65e2723800000000030304a9
# Copied data for poster_id 60e4f070000000000100599d, post_id 65def8cb000000000b020332
# Copied data for poster_id 60e4f070000000000100599d, post_id 65dbfb72000000000b02096c
# Copied data for poster_id 60e4f070000000000100599d, post_id 65da8a21000000000b0226b2
# Copied data for poster_id 60e4f070000000000100599d, post_id 65d806ae000000000b00f9bf
# Copied data for poster_id 60e4f070000000000100599d, post_id 65d69548000000000b022c5a
# Copied data for poster_id 60e4f070000000000100599d, post_id 65d40ece000000000b019cdf
# Copied data for poster_id 60e4f070000000000100599d, post_id 65d29a07000000000b01b98e
# Copied data for poster_id 60e4f070000000000100599d, post_id 65cd70cb000000000b00f063
# Copied data for poster_id 60e4f070000000000100599d, post_id 65c571d7000000001100c168
# Copied data for poster_id 60e4f070000000000100599d, post_id 65be0c3d000000000a030ecd
# Copied data for poster_id 60e4f070000000000100599d, post_id 65b9946c000000001100d8a7
# Copied data for poster_id 60e4f070000000000100599d, post_id 65b8415e0000000011000129
# Copied data for poster_id 60e4f070000000000100599d, post_id 65b703a7000000000a03113a
# Copied data for poster_id 60e4f070000000000100599d, post_id 65b3039e0000000011001f5d
# Copied data for poster_id 60e4f070000000000100599d, post_id 65ad4942000000001003fb02
# Copied data for poster_id 60e4f070000000000100599d, post_id 65a9bd180000000029016214
# Copied data for poster_id 60e4f070000000000100599d, post_id 65a47652000000001200acd8
# Copied data for poster_id 60e4f070000000000100599d, post_id 65a086e7000000001101bb17
# Copied data for poster_id 60e4f070000000000100599d, post_id 659b439b000000001001359b
# Copied data for poster_id 60e4f070000000000100599d, post_id 65a333ae000000000f01efa9
# Copied data for poster_id 60e4f070000000000100599d, post_id 6599f35600000000120022fa
# Copied data for poster_id 60e4f070000000000100599d, post_id 65991e4d000000000f01c7d2
# Copied data for poster_id 60e4f070000000000100599d, post_id 6597be99000000001101b236
# Copied data for poster_id 60e4f070000000000100599d, post_id 6595f6590000000011018fed
# Copied data for poster_id 60e4f070000000000100599d, post_id 6590d080000000001200425e
# Copied data for poster_id 60e4f070000000000100599d, post_id 658782b6000000000901d97f
# Copied data for poster_id 60e4f070000000000100599d, post_id 65862a3e000000000703b19f
# Copied data for poster_id 60e4f070000000000100599d, post_id 6584d43900000000090197eb
# Copied data for poster_id 60e4f070000000000100599d, post_id 658384b4000000000503948c
# Copied data for poster_id 60e4f070000000000100599d, post_id 6584282d000000000503a01a
# Copied data for poster_id 60e4f070000000000100599d, post_id 658234b90000000009019952
# Copied data for poster_id 60e4f070000000000100599d, post_id 658128610000000009021b1e
# Copied data for poster_id 60e4f070000000000100599d, post_id 657e4c610000000007038a50
# Copied data for poster_id 60e4f070000000000100599d, post_id 657cf7190000000007009431
# Copied data for poster_id 60e4f070000000000100599d, post_id 657a449f000000000901baab
# Copied data for poster_id 60e4f070000000000100599d, post_id 657715aa000000000703b154
# Copied data for poster_id 60e4f070000000000100599d, post_id 6573b4c40000000005038df4
# Copied data for poster_id 60e4f070000000000100599d, post_id 656e64da000000000902093b
# Copied data for poster_id 60e4f070000000000100599d, post_id 656d151f00000000050399bb
# Copied data for poster_id 60e4f070000000000100599d, post_id 656fbb9d000000000703ae28
# Copied data for poster_id 60e4f070000000000100599d, post_id 656bcabe000000000703a085
# Copied data for poster_id 60e4f070000000000100599d, post_id 6564784000000000320349af
# Copied data for poster_id 60e4f070000000000100599d, post_id 65628be7000000003202c323
# Copied data for poster_id 60e4f070000000000100599d, post_id 655ff06e000000003203194c
# Copied data for poster_id 60e4f070000000000100599d, post_id 655eac1300000000330050b1
# Copied data for poster_id 60e4f070000000000100599d, post_id 655d4edb000000000f027363
# Copied data for poster_id 60e4f070000000000100599d, post_id 655bf4fa00000000320312b4
# Copied data for poster_id 60e4f070000000000100599d, post_id 655aa6e6000000003202cff2
# Copied data for poster_id 60e4f070000000000100599d, post_id 655959570000000033001ef7
# Copied data for poster_id 60e4f070000000000100599d, post_id 65580c030000000032030050
# Copied data for poster_id 60e4f070000000000100599d, post_id 65540c39000000000f029cd2
# Copied data for poster_id 60e4f070000000000100599d, post_id 6552bab7000000003300311d
# Copied data for poster_id 60e4f070000000000100599d, post_id 6551736d0000000032037fc1
# Copied data for poster_id 60e4f070000000000100599d, post_id 6550206e00000000320317a9
# Copied data for poster_id 60e4f070000000000100599d, post_id 654c26670000000033000093
# Copied data for poster_id 60e4f070000000000100599d, post_id 65497f2600000000250217ac
# Copied data for poster_id 60e4f070000000000100599d, post_id 65482cbf000000002202eedf
# Copied data for poster_id 60e4f070000000000100599d, post_id 6545915d000000002500be4b
# Copied data for poster_id 60e4f070000000000100599d, post_id 6541f768000000002500904c
# Copied data for poster_id 60e4f070000000000100599d, post_id 6542e950000000002201c83a
# Copied data for poster_id 60e4f070000000000100599d, post_id 654193eb000000002202ce33
# Copied data for poster_id 60e4f070000000000100599d, post_id 653ef1e2000000002502326c
# Copied data for poster_id 60e4f070000000000100599d, post_id 653c59b1000000002501717b
# Copied data for poster_id 60e4f070000000000100599d, post_id 653affb5000000002402dacb
# Copied data for poster_id 60e4f070000000000100599d, post_id 65385c2f000000002502101b
# Copied data for poster_id 60e4f070000000000100599d, post_id 65370a71000000002303b70b
# Copied data for poster_id 60e4f070000000000100599d, post_id 6535b9d30000000025022bc2
# Copied data for poster_id 60e4f070000000000100599d, post_id 653468ca000000002402cf9c
# Copied data for poster_id 60e4f070000000000100599d, post_id 65332466000000002303b988
# Copied data for poster_id 60e4f070000000000100599d, post_id 6531c5c1000000002201d4ba
# Copied data for poster_id 60e4f070000000000100599d, post_id 6530ec06000000002500add7
# Copied data for poster_id 60e4f070000000000100599d, post_id 653072be000000002501641a
# Copied data for poster_id 60e4f070000000000100599d, post_id 652f483d000000001d039bed
# Copied data for poster_id 60e4f070000000000100599d, post_id 652dd0be000000001a021f62
# Copied data for poster_id 60e4f070000000000100599d, post_id 652c7f19000000002202885c
# Copied data for poster_id 60e4f070000000000100599d, post_id 652b3518000000001c0150f6
# Copied data for poster_id 60e4f070000000000100599d, post_id 6529e3dd000000002202988d
# Copied data for poster_id 60e4f070000000000100599d, post_id 65288447000000001c017535
# Copied data for poster_id 60e4f070000000000100599d, post_id 65273348000000001d03a225
# Copied data for poster_id 60e4f070000000000100599d, post_id 6525ec790000000022028f29
# Copied data for poster_id 60e4f070000000000100599d, post_id 652494cf000000001a014ded
# Copied data for poster_id 60e4f070000000000100599d, post_id 6521ef0d000000001d03bd98
# Copied data for poster_id 60e4f070000000000100599d, post_id 6520aabd000000001d0389f5
# Copied data for poster_id 60e4f070000000000100599d, post_id 651fb607000000002301b8a9
# Copied data for poster_id 60e4f070000000000100599d, post_id 651d5250000000001c015d06
# Copied data for poster_id 60e4f070000000000100599d, post_id 651cbf21000000001c017580
# Copied data for poster_id 60e4f070000000000100599d, post_id 651a963f000000002202ac06
# Copied data for poster_id 60e4f070000000000100599d, post_id 6518cc52000000001a014fd0
# Copied data for poster_id 60e4f070000000000100599d, post_id 65159ae40000000022028f3b
# Copied data for poster_id 60e4f070000000000100599d, post_id 65137021000000001a02275d
# Copied data for poster_id 60e4f070000000000100599d, post_id 6510d511000000001303d82a
# Copied data for poster_id 60e4f070000000000100599d, post_id 65121d0f0000000022028f6b
# Copied data for poster_id 60e4f070000000000100599d, post_id 650b889e000000001402561c
# Copied data for poster_id 60e4f070000000000100599d, post_id 65079fa2000000001303ff26
# Copied data for poster_id 60e4f070000000000100599d, post_id 6506561f000000001500bdfe
# Copied data for poster_id 60e4f070000000000100599d, post_id 65053dc90000000016031252
# Copied data for poster_id 60e4f070000000000100599d, post_id 6503a0d90000000016031d29
# Copied data for poster_id 60e4f070000000000100599d, post_id 64facb19000000001f03861a
# Copied data for poster_id 60e4f070000000000100599d, post_id 65002a98000000001e031314
# Copied data for poster_id 60e4f070000000000100599d, post_id 64fd9cf1000000001f03bddc
# Copied data for poster_id 60e4f070000000000100599d, post_id 64fbb6c90000000020001e4f
# Copied data for poster_id 60e4f070000000000100599d, post_id 64f7e2fb000000001e021eac
# Copied data for poster_id 60e4f070000000000100599d, post_id 64f6b42b000000001e02d584
# Copied data for poster_id 60e4f070000000000100599d, post_id 64f28813000000001f004b1b
# Copied data for poster_id 60e4f070000000000100599d, post_id 64efe89e000000001e021d2d
# Copied data for poster_id 60e4f070000000000100599d, post_id 64ee92c1000000001f0043e8
# Copied data for poster_id 60e4f070000000000100599d, post_id 64eaac0b0000000012018c4c
# Copied data for poster_id 60e4f070000000000100599d, post_id 64e96c5e000000000301c97e
# Copied data for poster_id 60e4f070000000000100599d, post_id 64e73a83000000000c036ba4
# Copied data for poster_id 60e4f070000000000100599d, post_id 64e411a4000000001201c6a4
# Copied data for poster_id 60e4f070000000000100599d, post_id 64e16c7c0000000012018334
# Copied data for poster_id 60e4f070000000000100599d, post_id 64deb699000000000103df1b
# Copied data for poster_id 60e4f070000000000100599d, post_id 64dd64e20000000017018d4c
# Copied data for poster_id 60e4f070000000000100599d, post_id 64da15a1000000000800f6cd
# Copied data for poster_id 60e4f070000000000100599d, post_id 64d82c6a000000000800ff0a
# Copied data for poster_id 60e4f070000000000100599d, post_id 64d6d286000000001701b5f3
# Copied data for poster_id 60e4f070000000000100599d, post_id 64d4c0c8000000001701a61d
# Copied data for poster_id 60e4f070000000000100599d, post_id 64d19b78000000000a01b002
# Copied data for poster_id 60e4f070000000000100599d, post_id 64cd8efc000000001201d929
# Copied data for poster_id 60e4f070000000000100599d, post_id 64d2d742000000000a01bee6
# Copied data for poster_id 60e4f070000000000100599d, post_id 64c90b53000000000c037b47
# Copied data for poster_id 60e4f070000000000100599d, post_id 64c1bb510000000010030f95
# Copied data for poster_id 60e4f070000000000100599d, post_id 64bde151000000000103d90d
# Copied data for poster_id 60e4f070000000000100599d, post_id 64b93cfc000000000a01a4b4
# Copied data for poster_id 60e4f070000000000100599d, post_id 64b5de230000000031008d59
# Copied data for poster_id 60e4f070000000000100599d, post_id 64b33fc1000000001c0181eb
# Copied data for poster_id 60e4f070000000000100599d, post_id 64af51330000000016024c9d
# Copied data for poster_id 60e4f070000000000100599d, post_id 64ab5e59000000002b03f187
# Copied data for poster_id 60e4f070000000000100599d, post_id 64a8ce9a000000001c019ef8
# Copied data for poster_id 60e4f070000000000100599d, post_id 64a4bd22000000003102d2da
# Copied data for poster_id 60e4f070000000000100599d, post_id 64a36023000000001c00e79f
# Copied data for poster_id 60e4f070000000000100599d, post_id 649e1beb0000000011013e6d
# Copied data for poster_id 60e4f070000000000100599d, post_id 64a224570000000013009d18
# ...
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 658bf170000000001d0248d7
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 658bf08c000000001d0144ea
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 65785a8c000000003403caa3
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 654b6778000000001b036721
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 6541ea92000000001e022c95
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 654b6d3f000000001100e30c
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 6541e95d000000001e031b0d
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 6522e902000000001d017ddf
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64fdd838000000001f03d220
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64fdd5c4000000001d015dbe
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64fdd532000000001f03ba12
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64fb3d4e000000001f03c89c
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64e5b591000000000800d670
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64db2167000000000a0196e0
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64db215d0000000003023594
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64db19cd000000001700eb28
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64d5d316000000000b028535
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64e5b929000000000103c5fc
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64db215400000000030234d9
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64d5d0b8000000000800f341
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64d5cf850000000012018a96
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64c0d679000000000b02a7bb
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64c0d571000000001201d98a
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64c0d4eb000000000103f678
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64c0d495000000000800d277
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 6491896a000000002701045e
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 649188cf0000000013001fbd
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 6491882c000000001303ee55
# Copied data for poster_id 61d74f0d0000000002019e9c, post_id 64c0d3eb0000000010031fa9
# Copied data for poster_id 5c4586d0000000000501b6e4, post_id 6568837c0000000038020367
# Copied data for poster_id 5c4586d0000000000501b6e4, post_id 653a49110000000020003ebf
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64da34e5000000000800c4d1
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64d5e13f000000000103fbdf
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64d3730a000000000a01a146
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64ccb3d0000000000c0344c5
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64d0edb60000000012018076
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64cbb74b000000001700d5d7
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64c9142c000000000800eda9
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64c66935000000000c0344aa
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64bb4e1d000000000c036ae0
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64bf7bc5000000001700c2a5
# Copied data for poster_id 5c5446fe000000001b03f358, post_id 64bcb0d9000000000103db5d
# Copied data for poster_id 6082a7320000000001009da5, post_id 658be705000000001101908f
# Copied data for poster_id 6082a7320000000001009da5, post_id 6580f61e000000000801f359
# Copied data for poster_id 6082a7320000000001009da5, post_id 65783e270000000007009b84
# Copied data for poster_id 6082a7320000000001009da5, post_id 65671b4b00000000330057c5
# Copied data for poster_id 6082a7320000000001009da5, post_id 656143cc000000003202e3fb
# Copied data for poster_id 6082a7320000000001009da5, post_id 655dddda000000003300660c
# Copied data for poster_id 6082a7320000000001009da5, post_id 655b385500000000330088ab
# Copied data for poster_id 6082a7320000000001009da5, post_id 65548ef7000000000f028986
# Copied data for poster_id 6082a7320000000001009da5, post_id 64fc7492000000001f03f211
# Copied data for poster_id 6082a7320000000001009da5, post_id 64dcae2b000000000b02ad12
# Copied data for poster_id 6082a7320000000001009da5, post_id 64d0c429000000000b02b525
# Copied data for poster_id 6082a7320000000001009da5, post_id 64b27b16000000001e01a776
# Copied data for poster_id 6082a7320000000001009da5, post_id 64abe5ed000000000f00f092
# Copied data for poster_id 6082a7320000000001009da5, post_id 64a033830000000007039d5f
# Copied data for poster_id 6082a7320000000001009da5, post_id 6497120a0000000013007f7f
# Copied data for poster_id 6082a7320000000001009da5, post_id 648f110c0000000013006793
# Copied data for poster_id 6082a7320000000001009da5, post_id 648a7249000000001203c6a4
# Copied data for poster_id 6082a7320000000001009da5, post_id 64813895000000001303650f
# Copied data for poster_id 6082a7320000000001009da5, post_id 647c6d98000000001203d9e3
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 658f9c3c000000001e007347
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 658d8210000000001102d3a3
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6588ea5b0000000038022ac1
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6583ee11000000001502d2ad
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6582aa6a000000003a00ab55
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 65816174000000003c01122d
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 65804339000000001502c103
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 657ff04d000000003403e437
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 657db747000000003a00c56e
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 657bb080000000003a00ac43
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6576e602000000001502fc4f
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6572b05c00000000380286ff
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 656d3cbd000000003c012025
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 65597f6e000000003200be68
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 655718b6000000001100f07a
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6551df0e0000000032000733
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 654c4c0b0000000032026544
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6552ef07000000001100d39d
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 653c855d000000001f006aa7
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 653b8bda000000001e00fdc4
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 65309ae5000000001f0387dd
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 6528f773000000001f037a5d
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 651f51a3000000001e02adce
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 651bc240000000001f037ed8
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 65169ee4000000001e02f6ea
# Copied data for poster_id 63b3bdbf000000002702bf54, post_id 65143881000000001f0040ca
# Copied data for poster_id 5ca5aabc0000000016026bf5, post_id 657f0a90000000003802cfbb
# Copied data for poster_id 5ca5aabc0000000016026bf5, post_id 65003e5d000000001e00f16d
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 658ad3fa000000000f01125c
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65818e490000000006023af1
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 657bfe6b00000000070089e1
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6579286d00000000090180e1
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65792145000000000801f6dd
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65791fee00000000060209df
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65791edb000000000801e84f
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6577087900000000060235ef
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6571d8e6000000000801f3d2
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65716b54000000000901bf6d
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65715c020000000005039c5f
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 656f22a6000000000901cf88
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6569473d000000003300bc56
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6569441d000000003202efc1
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65693d350000000032032fad
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65693bc20000000033005fc1
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 656847140000000032039a1c
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6566fcea000000000f0240e0
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65646ea6000000003203b4c8
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 655f360d0000000033008b5e
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 655f2fdb000000000f0245c3
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 655e0a07000000000f0247c5
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6558c65c000000003300836a
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 65572ae200000000330057fb
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 655714ec00000000330099a6
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6555db3600000000320350a3
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6555ca08000000003202d954
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6554ceda00000000320328a1
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6554cc1d000000003202e396
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 6551dbd3000000003202ef54
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 654b84db0000000033007dfd
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 654b7bd0000000000f02486d
# Copied data for poster_id 6361bfbe000000001f01beb4, post_id 64d103560000000010032d2c
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 658ac778000000001102f8d2
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 6569e854000000003c013348
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 656897570000000038024e08
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 65647c0b0000000010003dd5
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 65634e7600000000320295bf
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 65411364000000001f038f54
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 6540f5c8000000002000182e
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 6534e34e000000001f0373e2
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 650455e30000000020003807
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 64fc8306000000001f00458f
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 64f6c8c0000000001e030311
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 64f6c7fd000000001f007ddb
# Copied data for poster_id 610ac0c6000000000100a7fc, post_id 64e8b007000000000103ccf8
# Copied data for poster_id 5e2056ad0000000001001053, post_id 65787aa800000000380210f9
# Copied data for poster_id 5e2056ad0000000001001053, post_id 6575ab2b0000000038015427
# Copied data for poster_id 5e2056ad0000000001001053, post_id 6579b855000000003a00db53
# Copied data for poster_id 5e2056ad0000000001001053, post_id 656356b00000000032000e74
# Copied data for poster_id 5e2056ad0000000001001053, post_id 65609220000000001f02ede2
# Copied data for poster_id 5e2056ad0000000001001053, post_id 6557268d000000001b036360
# Copied data for poster_id 5e2056ad0000000001001053, post_id 6556fc21000000001b00f568
# Copied data for poster_id 5e2056ad0000000001001053, post_id 65550a06000000003200127b
# Copied data for poster_id 5e2056ad0000000001001053, post_id 6554f654000000003202a34b
# Copied data for poster_id 5d2000a600000000110192c1, post_id 65150d7d000000002101e8e8
# Copied data for poster_id 5ddfcec5000000000100899b, post_id 64885949000000000800c101
# Copied data for poster_id 630a1855000000000f0070a6, post_id 657002c00000000038028560
# Copied data for poster_id 630a1855000000000f0070a6, post_id 653cb718000000001e031632
# Copied data for poster_id 5cf72ea30000000012022df6, post_id 6562c1b4000000003202cdbb
# Copied data for poster_id 5cf72ea30000000012022df6, post_id 64894fd5000000001300ceb4
# Copied data for poster_id 5cf72ea30000000012022df6, post_id 648036f10000000011011dbc
# Copied data for poster_id 5cf72ea30000000012022df6, post_id 647f111c000000001303d4ae
# Copied data for poster_id 5cf72ea30000000012022df6, post_id 647c33360000000013004e92
# Copied data for poster_id 60121dc40000000001005958, post_id 6590f31d000000001103152c
# Copied data for poster_id 60121dc40000000001005958, post_id 658116b4000000003a00b2a8
# Copied data for poster_id 60121dc40000000001005958, post_id 657c58fb00000000380311bf
# Copied data for poster_id 60121dc40000000001005958, post_id 657bc7d20000000038033624
# Copied data for poster_id 60121dc40000000001005958, post_id 65768446000000003802c58d
# Copied data for poster_id 60121dc40000000001005958, post_id 657152620000000016005cb0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 31
#      28 # Check if the source folder exists
#      29 if os.path.exists(source_post_folder):
#      30     # Copy the entire post_id folder to the destination
# ---> 31     shutil.copytree(source_post_folder, dest_post_folder, dirs_exist_ok=True)
#      32     print(f"Copied data for poster_id {poster_id}, post_id {post_id}")
#      33 else:
#
# File /opt/tljh/user/lib/python3.9/shutil.py:565, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     563 with os.scandir(src) as itr:
#     564     entries = list(itr)
# --> 565 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     566                  ignore=ignore, copy_function=copy_function,
#     567                  ignore_dangling_symlinks=ignore_dangling_symlinks,
#     568                  dirs_exist_ok=dirs_exist_ok)
#
# File /opt/tljh/user/lib/python3.9/shutil.py:507, in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     503         copytree(srcobj, dstname, symlinks, ignore, copy_function,
#     504                  dirs_exist_ok=dirs_exist_ok)
#     505     else:
#     506         # Will raise a SpecialFileError for unsupported file types
# --> 507         copy_function(srcobj, dstname)
#     508 # catch the Error from the recursive copytree so that we can
#     509 # continue with other files
#     510 except Error as err:
#
# File /opt/tljh/user/lib/python3.9/shutil.py:443, in copy2(src, dst, follow_symlinks)
#     441 if os.path.isdir(dst):
#     442     dst = os.path.join(dst, os.path.basename(src))
# --> 443 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     444 copystat(src, dst, follow_symlinks=follow_symlinks)
#     445 return dst
#
# File /opt/tljh/user/lib/python3.9/shutil.py:276, in copyfile(src, dst, follow_symlinks)
#     274 elif _USE_CP_SENDFILE:
#     275     try:
# --> 276         _fastcopy_sendfile(fsrc, fdst)
#     277         return dst
#     278     except _GiveupOnFastCopy:
#
# File /opt/tljh/user/lib/python3.9/shutil.py:152, in _fastcopy_sendfile(fsrc, fdst)
#     150 while True:
#     151     try:
# --> 152         sent = os.sendfile(outfd, infd, offset, blocksize)
#     153     except OSError as err:
#     154         # ...in oder to have a more informative exception.
#     155         err.filename = fsrc.name
#
# KeyboardInterrupt:

# %% [markdown]
# Count the number of poster_id directories in the all_data or test/data folder:

# %%
import os

# Define the path to the all_data folder
all_data_folder = '/home/disk1/red_disk1/all_data'
# all_data_folder = '/home/disk1/red_disk1/test/data'

# Get a list of all items in the all_data folder
all_items = os.listdir(all_data_folder)

# Filter the list to include only directories (which represent poster_id)
poster_ids = [item for item in all_items if os.path.isdir(os.path.join(all_data_folder, item))]

# Count the number of poster_id directories
num_poster_ids = len(poster_ids)

# Initialize a set to store unique post_ids
unique_post_ids = set()

# Iterate through each poster_id directory to count distinct post_id files
for poster_id in poster_ids:
    poster_id_path = os.path.join(all_data_folder, poster_id)
    post_files = os.listdir(poster_id_path)
    for post_file in post_files:
        post_id, _ = os.path.splitext(post_file)  # Extract post_id without file extension
        unique_post_ids.add(post_id)

# Count the number of distinct post_ids
num_post_ids = len(unique_post_ids)

# Print the results
print(f"There are {num_poster_ids} poster_id directories in the test/data folder.")
print(f"There are {num_post_ids} distinct post_id files in the test/data folder.")
# Out:
# There are 10335 poster_id directories in the test/data folder.
# There are 709613 distinct post_id files in the test/data folder.
