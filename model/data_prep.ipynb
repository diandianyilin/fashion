# %% [markdown]
# Select 200 distinct rows based on poster_id from poster_got_50w.csv and save the result in poster_test_200.csv

# %%
import pandas as pd

# Define the file path
file_path = '/home/disk1/red_disk1/poster_got_50w.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Select 50 distinct poster_id
distinct_poster_ids = df['poster_id'].drop_duplicates().head(300)

# Filter the DataFrame to include only rows with the selected poster_id
filtered_rows = df[df['poster_id'].isin(distinct_poster_ids)]

# Save the new DataFrame to a CSV file
output_path = '/home/disk1/red_disk1/test/poster_test_300.csv'
filtered_rows.to_csv(output_path, index=False)

print(f"New CSV file with rows corresponding to 300 distinct poster_id saved as 'poster_test_50.csv'")
# Out:
# New CSV file with rows corresponding to 300 distinct poster_id saved as 'poster_test_50.csv'

# %% [markdown]
# #### Keep fashion posts only
#
# 1. Filter rows containing fashion-related keywords in 'post_title' or 'post_content'
# 2. Remove posts with no post_date or post_like or post_collect or post_comments
# 3. Set time range from 2023-06-01 to 2024-05-31 to ensure exactly one year

# %%
import pandas as pd
import re

# Define the path to the CSV file
file_path = '/home/disk1/red_disk1/poster_got_50w.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Convert 'post_date' to datetime format
df['post_date'] = pd.to_datetime(df['post_date'], errors='coerce')

# Define the date range
start_date = '2023-06-01'
end_date = '2024-05-31'

# Filter rows based on the date range
df = df[(df['post_date'] >= start_date) & (df['post_date'] <= end_date)]

# Define fashion-related keywords
fashion_keywords = [
    "时尚", "穿搭", "搭配", "潮流", "服装", "造型", "衣服", "新品", "裙子", "裤子", "连衣裙", 
    "上衣", "衬衫", "外套", "牛仔裤", "毛衣", "包包", "鞋子", "首饰", "帽子", "眼镜", "简约", 
    "休闲", "正式", "甜美", "酷", "时髦", "复古", "韩系", "日系", "轻奢", "#OOTD", "#Ootd", 
    "#ootd", "#时尚达人", "#穿搭指南", "#今日穿搭", "#潮流搭配", "#时尚博主", "#新品推荐", 
    "#街拍", "#每日穿搭", "#名牌", "夏装", "冬装", "春装", "秋装", "节日", "婚礼"
]

# Create a regex pattern for the fashion keywords
pattern = re.compile('|'.join(fashion_keywords), re.IGNORECASE)

# Filter rows containing fashion-related keywords in 'post_title' or 'post_content'
df_fashion = df[df['post_title'].str.contains(pattern, na=False) | df['post_content'].str.contains(pattern, na=False)]

# Remove rows with missing information in the specified columns
df_fashion_cleaned = df_fashion.dropna(subset=['post_date', 'post_like', 'post_collect', 'post_comments'])

# Count the number of distinct poster_id and post_id
num_distinct_poster_id = df_fashion_cleaned['poster_id'].nunique()
num_distinct_post_id = df_fashion_cleaned['post_id'].nunique()

# Print the counts
print(f"There are {num_distinct_poster_id} distinct poster_id in the filtered data.")
print(f"There are {num_distinct_post_id} distinct post_id in the filtered data.")

# Save the updated DataFrame to a new CSV file
output_path = '/home/disk1/red_disk1/test/poster_test_fashion.csv'
df_fashion_cleaned.to_csv(output_path, index=False)

print("Filtered data has been saved to", output_path)
# Out:
# There are 294 distinct poster_id in the filtered data.
# There are 24145 distinct post_id in the filtered data.
# Filtered data has been saved to /home/disk1/red_disk1/test/poster_test_fashion.csv

# %% [markdown]
# Select the data from the all_data folder based on poster_id and post_id in poster_test_fashion.csv

# %%
import pandas as pd
import os
import shutil

# Define the file paths
csv_file_path = '/home/disk1/red_disk1/test/poster_test_fashion.csv'
all_data_folder = '/home/disk1/red_disk1/all_data'
output_folder = '/home/disk1/red_disk1/test/data'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load the CSV file
df = pd.read_csv(csv_file_path)

# Iterate over each unique combination of poster_id and post_id
for _, row in df.iterrows():
    poster_id = str(row['poster_id'])
    post_id = str(row['post_id'])
    
    # Define the source folder path
    source_post_folder = os.path.join(all_data_folder, poster_id, post_id)
    
    # Define the destination folder path
    dest_post_folder = os.path.join(output_folder, poster_id, post_id)
    
    # Check if the source folder exists
    if os.path.exists(source_post_folder):
        # Copy the entire post_id folder to the destination
        shutil.copytree(source_post_folder, dest_post_folder, dirs_exist_ok=True)
        print(f"Copied data for poster_id {poster_id}, post_id {post_id}")
    else:
        print(f"Source folder for poster_id {poster_id}, post_id {post_id} does not exist")

print("Data selection completed.")
# Out:
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 663ef7c0000000001e0331ce
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 6639986d000000001e032d08
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 663771d0000000001e03b7ba
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 6629ba080000000001032110
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 6618a4c5000000001a0173a9
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 660f60fa000000001a017c51
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 660a9548000000001a0123f5
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 65faa1c50000000012021bce
# Copied data for poster_id 5659a9f903eb841795e4fba9, post_id 65c1eb2c000000002d0038ca
# Copied data for poster_id 5f0357c10000000001001d74, post_id 66121a5f000000001a01507b
# Copied data for poster_id 5f0357c10000000001001d74, post_id 66023d4a000000000d00d738
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65f90b02000000001203e0f4
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65f4f863000000000d00fbdd
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65e935080000000004002915
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65d6c5c50000000007005268
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65a95f3c000000002b00b38b
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65a747ae000000002a01401d
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65a4b144000000001d027ae1
# Copied data for poster_id 5f0357c10000000001001d74, post_id 6594d0b6000000001d016790
# Copied data for poster_id 5f0357c10000000001001d74, post_id 658577970000000034035a51
# Copied data for poster_id 5f0357c10000000001001d74, post_id 658273680000000016006e8b
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65812c35000000003c013a07
# Copied data for poster_id 5f0357c10000000001001d74, post_id 657bca3a0000000034034604
# Copied data for poster_id 5f0357c10000000001001d74, post_id 656aa84a0000000038028a67
# Copied data for poster_id 5f0357c10000000001001d74, post_id 655ebfdb000000001f02fb1e
# Copied data for poster_id 5f0357c10000000001001d74, post_id 6539d66a000000001f03ad68
# Copied data for poster_id 5f0357c10000000001001d74, post_id 65389643000000001e023299
# Copied data for poster_id 5f0357c10000000001001d74, post_id 6530cdf4000000001e00eea9
# Copied data for poster_id 5f0357c10000000001001d74, post_id 650ea8e9000000001f00740f
# Copied data for poster_id 5f0357c10000000001001d74, post_id 64e19c80000000000301d532
# Copied data for poster_id 5f0357c10000000001001d74, post_id 64dfb68b0000000010033d60
# Copied data for poster_id 5965ebab50c4b438acc7a2e4, post_id 66337bb8000000001e024982
# Copied data for poster_id 5965ebab50c4b438acc7a2e4, post_id 662f8a4b000000001e01c90e
# Copied data for poster_id 5ed0b272000000000100204d, post_id 66594e48000000001501363d
# Copied data for poster_id 5ed0b272000000000100204d, post_id 6654744e000000000c01acee
# Copied data for poster_id 5ed0b272000000000100204d, post_id 665085b2000000000c01bc53
# Copied data for poster_id 5ed0b272000000000100204d, post_id 664d6ea8000000001303df9e
# Copied data for poster_id 5f8319b90000000001005167, post_id 665991d2000000000f00d99d
# Copied data for poster_id 5f8319b90000000001005167, post_id 6655aabb000000000f00e9bc
# Copied data for poster_id 5f8319b90000000001005167, post_id 6654598f000000001303c4c3
# Copied data for poster_id 5f8319b90000000001005167, post_id 6651b63400000000150137f4
# Copied data for poster_id 5f8319b90000000001005167, post_id 665065d000000000150101ee
# Copied data for poster_id 5f8319b90000000001005167, post_id 664f131900000000150100f5
# Copied data for poster_id 5f8319b90000000001005167, post_id 664dbb0500000000150093d9
# Copied data for poster_id 5f8319b90000000001005167, post_id 664b1750000000000c0180d9
# Copied data for poster_id 5f8319b90000000001005167, post_id 66472240000000000f00ce20
# Copied data for poster_id 5f8319b90000000001005167, post_id 6645cbc1000000001e027602
# Copied data for poster_id 5f8319b90000000001005167, post_id 66432903000000001e024acb
# Copied data for poster_id 5f8319b90000000001005167, post_id 663de902000000001e02e2a8
# Copied data for poster_id 5f8319b90000000001005167, post_id 663b3fbd000000001e02dce8
# Copied data for poster_id 5f8319b90000000001005167, post_id 6639eddf000000001e02df02
# Copied data for poster_id 5f8319b90000000001005167, post_id 6634a0bf000000001e01e056
# Copied data for poster_id 5f8319b90000000001005167, post_id 662f6e9a000000001e01e3e2
# Copied data for poster_id 5f8319b90000000001005167, post_id 662ccec9000000001c006544
# Copied data for poster_id 5f8319b90000000001005167, post_id 662a24c1000000000d030612
# Copied data for poster_id 5f8319b90000000001005167, post_id 6628cb19000000001c005665
# Copied data for poster_id 5f8319b90000000001005167, post_id 6627793f000000000d032610
# Copied data for poster_id 5f8319b90000000001005167, post_id 6624dd10000000000302142e
# Copied data for poster_id 5f8319b90000000001005167, post_id 662234b1000000001c00581d
# Copied data for poster_id 5f8319b90000000001005167, post_id 661e4c06000000001c006733
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 6656eec3000000000c019490
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 6650477e000000001303db2e
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 6646fa5e00000000150115a4
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 663cae02000000001e01d8b9
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 663a0a64000000001e01bf1a
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 6630af66000000001e020af1
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 6630b365000000001e01f784
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 662b3d7a000000001c007467
# Copied data for poster_id 54cd4264b4c4d615fc2c8785, post_id 6628f23e000000001c00bf11
# Copied data for poster_id 5ee6f0b7000000000101efc1, post_id 66546c8b0000000014018c3e
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 663a00d9000000001e03a1e5
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 66360c58000000001e03a013
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 66336979000000001e034215
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 662f7469000000001e038a33
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 662cd18500000000010315f7
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 66237e930000000001005bff
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 66278ba20000000004018830
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 6623980c0000000001030d3d
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 6620f435000000000100495a
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 661e51270000000004019e47
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 661a4f6b000000001a0121f0
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 6617b97e000000001a01261b
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 661516d2000000001a00f17a
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 661122d9000000001a017711
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 660e7f0d000000001a013ba5
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 660bdc18000000001a0100a2
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 6607e81b000000001a015c5f
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 660544d0000000001203d69c
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 6602a199000000000d00d832
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 65feaf07000000001203f4d2
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 65fc0b84000000001203f4eb
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 65f96723000000001203ddad
# Copied data for poster_id 58c116366a6a69510d4d5fca, post_id 

# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 649bd8cb0000000013033161
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 649a833a0000000013006b28
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 64942722000000001303c7fc
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 6492e1df000000000703840c
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 648ff2430000000013005f2c
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 648eb47b00000000270007a5
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 648954f100000000130119af
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 6486801e000000001300c6cc
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 6482ec440000000014024682
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 647f3b640000000013005453
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 647b5ef7000000001303da5e
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 6479754f000000001300f685
# Copied data for poster_id 5a028c1011be1014ba3439ec, post_id 64783c3900000000130067ff
# Copied data for poster_id 56e771671c07df425877e731, post_id 65ddd2f6000000000b018440
# Copied data for poster_id 56e771671c07df425877e731, post_id 65ce0521000000000b00e61c
# Copied data for poster_id 56e771671c07df425877e731, post_id 65bce1a8000000000201301d
# Copied data for poster_id 56e771671c07df425877e731, post_id 65afb0260000000011012162
# Copied data for poster_id 56e771671c07df425877e731, post_id 6597f2c6000000001000ea46
# Copied data for poster_id 56e771671c07df425877e731, post_id 658d23730000000010010a9b
# Copied data for poster_id 56e771671c07df425877e731, post_id 657ad095000000000801fbc9
# Copied data for poster_id 56e771671c07df425877e731, post_id 6578500500000000050399ee
# Copied data for poster_id 56e771671c07df425877e731, post_id 65634b59000000000f029eaa
# Copied data for poster_id 56e771671c07df425877e731, post_id 654e2b55000000000f027bbc
# Copied data for poster_id 56e771671c07df425877e731, post_id 654b4256000000000f029145
# Copied data for poster_id 56e771671c07df425877e731, post_id 654a2cf9000000000f029e73
# Copied data for poster_id 56e771671c07df425877e731, post_id 65410469000000002500becb
# Copied data for poster_id 56e771671c07df425877e731, post_id 65362d88000000002201e580
# Copied data for poster_id 56e771671c07df425877e731, post_id 652fcfca000000002202ed7c
# Copied data for poster_id 56e771671c07df425877e731, post_id 652a9b6d000000001a014164
# Copied data for poster_id 56e771671c07df425877e731, post_id 651ab8e9000000001c017d5d
# Copied data for poster_id 56e771671c07df425877e731, post_id 6515316d000000001d038585
# Data selection completed.

# %% [markdown]
# Count the number of poster_id directories in the all_data or test/data folder:

# %%
import os

# Define the path to the all_data folder
all_data_folder = '/home/disk1/red_disk1/all_data'
# all_data_folder = '/home/disk1/red_disk1/test/data'

# Get a list of all items in the all_data folder
all_items = os.listdir(all_data_folder)

# Filter the list to include only directories (which represent poster_id)
poster_ids = [item for item in all_items if os.path.isdir(os.path.join(all_data_folder, item))]

# Count the number of poster_id directories
num_poster_ids = len(poster_ids)

# Initialize a set to store unique post_ids
unique_post_ids = set()

# Iterate through each poster_id directory to count distinct post_id files
for poster_id in poster_ids:
    poster_id_path = os.path.join(all_data_folder, poster_id)
    post_files = os.listdir(poster_id_path)
    for post_file in post_files:
        post_id, _ = os.path.splitext(post_file)  # Extract post_id without file extension
        unique_post_ids.add(post_id)

# Count the number of distinct post_ids
num_post_ids = len(unique_post_ids)

# Print the results
print(f"There are {num_poster_ids} poster_id directories in the test/data folder.")
print(f"There are {num_post_ids} distinct post_id files in the test/data folder.")
# Out:
# There are 10335 poster_id directories in the test/data folder.
# There are 709613 distinct post_id files in the test/data folder.
