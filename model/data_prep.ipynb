# %% [markdown]
# Select 200 distinct rows based on poster_id from poster_got_50w.csv and save the result in poster_test_200.csv

# %%
import pandas as pd

# Define the file path
file_path = '/home/disk1/red_disk1/poster_got_50w.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Select 50 distinct poster_id
distinct_poster_ids = df['poster_id'].drop_duplicates().head(300)

# Filter the DataFrame to include only rows with the selected poster_id
filtered_rows = df[df['poster_id'].isin(distinct_poster_ids)]

# Save the new DataFrame to a CSV file
output_path = '/home/disk1/red_disk1/test/poster_test_300.csv'
filtered_rows.to_csv(output_path, index=False)

print(f"New CSV file with rows corresponding to 300 distinct poster_id saved as 'poster_test_50.csv'")
# Out:
# New CSV file with rows corresponding to 300 distinct poster_id saved as 'poster_test_50.csv'

# %% [markdown]
# #### Keep fashion posts only
#
# 1. Filter rows containing fashion-related keywords in 'post_title' or 'post_content'
# 2. Remove posts with no post_date or post_like or post_collect or post_comments
# 3. Set time range from 2023-06-01 to 2024-05-31 to ensure exactly one year

# %%
import pandas as pd
import re

# Define the path to the CSV file
file_path = '/home/disk1/red_disk1/test/poster_test_300.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Convert 'post_date' to datetime format
df['post_date'] = pd.to_datetime(df['post_date'], errors='coerce')

# Define the date range
start_date = '2023-06-01'
end_date = '2024-05-31'

# Filter rows based on the date range
df = df[(df['post_date'] >= start_date) & (df['post_date'] <= end_date)]

# Define fashion-related keywords
fashion_keywords = [
    "时尚", "穿搭", "搭配", "潮流", "服装", "造型", "衣服", "新品", "裙子", "裤子", "连衣裙", 
    "上衣", "衬衫", "外套", "牛仔裤", "毛衣", "包包", "鞋子", "首饰", "帽子", "眼镜", "简约", 
    "休闲", "正式", "甜美", "酷", "时髦", "复古", "韩系", "日系", "轻奢", "#OOTD", "#Ootd", 
    "#ootd", "#时尚达人", "#穿搭指南", "#今日穿搭", "#潮流搭配", "#时尚博主", "#新品推荐", 
    "#街拍", "#每日穿搭", "#名牌", "夏装", "冬装", "春装", "秋装", "节日", "婚礼"
]

# Create a regex pattern for the fashion keywords
pattern = re.compile('|'.join(fashion_keywords), re.IGNORECASE)

# Filter rows containing fashion-related keywords in 'post_title' or 'post_content'
df_fashion = df[df['post_title'].str.contains(pattern, na=False) | df['post_content'].str.contains(pattern, na=False)]

# Remove rows with missing information in the specified columns
df_fashion_cleaned = df_fashion.dropna(subset=['post_date', 'post_like', 'post_collect', 'post_comments'])

# Count the number of distinct poster_id and post_id
num_distinct_poster_id = df_fashion_cleaned['poster_id'].nunique()
num_distinct_post_id = df_fashion_cleaned['post_id'].nunique()

# Print the counts
print(f"There are {num_distinct_poster_id} distinct poster_id in the filtered data.")
print(f"There are {num_distinct_post_id} distinct post_id in the filtered data.")

# Save the updated DataFrame to a new CSV file
output_path = '/home/disk1/red_disk1/test/poster_test_fashion.csv'
df_fashion_cleaned.to_csv(output_path, index=False)

print("Filtered data has been saved to", output_path)
# Out:
# There are 289 distinct poster_id in the filtered data.
# There are 23760 distinct post_id in the filtered data.
# Filtered data has been saved to /home/disk1/red_disk1/test/poster_test_fashion.csv

# %% [markdown]
# Select the data from the all_data folder based on poster_id and post_id in poster_test_fashion.csv

# %%
import pandas as pd
import os
import shutil

# Define the file paths
csv_file_path = '/home/disk1/red_disk1/test/poster_test_fashion.csv'
all_data_folder = '/home/disk1/red_disk1/all_data'
output_folder = '/home/disk1/red_disk1/test/data'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load the CSV file
df = pd.read_csv(csv_file_path)

# Iterate over each unique poster_id
for poster_id in df['poster_id'].unique():
    poster_id = str(poster_id)
    
    # Define the source folder path
    source_poster_folder = os.path.join(all_data_folder, poster_id)
    
    # Define the destination folder path
    dest_poster_folder = os.path.join(output_folder, poster_id)
    
    # Check if the source folder exists
    if os.path.exists(source_poster_folder):
        # Copy the entire poster_id folder to the destination
        shutil.copytree(source_poster_folder, dest_poster_folder, dirs_exist_ok=True)
        print(f"Copied all data for poster_id {poster_id}")
    else:
        print(f"Source folder for poster_id {poster_id} does not exist")

print("Data selection completed.")
# Out:
# Copied all data for poster_id 5659a9f903eb841795e4fba9
# Copied all data for poster_id 5f0357c10000000001001d74
# Copied all data for poster_id 5a8cf39111be10466d285d6b
# Copied all data for poster_id 5bde6c582572a10001b75ca4
# Copied all data for poster_id 5dcc3548000000000100bcbc
# Copied all data for poster_id 5b4da579e8ac2b2fae53447e
# Copied all data for poster_id 5bd6dcc813feb70001c0fb10
# Copied all data for poster_id 59ded8396eea880cdd9dde05
# Copied all data for poster_id 5f09d4a800000000010076a1
# Copied all data for poster_id 58ce075f5e87e757f8ea60c9
# Copied all data for poster_id 647075c6000000002a0377f6
# Copied all data for poster_id 57a346a67fc5b869366dd8f9
# Copied all data for poster_id 5aa33f5411be106b050fab2c
# Copied all data for poster_id 5958d3d56a6a691265623f01
# Copied all data for poster_id 5c454bb900000000070116a5
# Copied all data for poster_id 5b7702314115e000010bd9f5
# Copied all data for poster_id 598cb9e45e87e703113a4b42
# Copied all data for poster_id 5b1bb0f311be10296312808d
# Copied all data for poster_id 5b9f6f33b2e7dc000145640f
# Copied all data for poster_id 59ef0b1211be105e76cffae6
# Copied all data for poster_id 604b90000000000001003ae8
# Copied all data for poster_id 5b3c364911be10556aeb83ef
# Copied all data for poster_id 6357ba44000000001901fdec
# Copied all data for poster_id 5a9a74dd11be1053476212dd
# Copied all data for poster_id 579dc04982ec39466917e9c6
# Copied all data for poster_id 5965ebab50c4b438acc7a2e4
# Copied all data for poster_id 5ed0b272000000000100204d
# Copied all data for poster_id 5f8319b90000000001005167
# Copied all data for poster_id 54cd4264b4c4d615fc2c8785
# Copied all data for poster_id 5ee6f0b7000000000101efc1
# Copied all data for poster_id 58c116366a6a69510d4d5fca
# Copied all data for poster_id 5a20fd8e4eacab7ff7591319
# Copied all data for poster_id 55a25030b7ba2215ba75dea8
# Copied all data for poster_id 5e00388400000000010097d2
# Copied all data for poster_id 5c54fd6d000000001803403f
# Copied all data for poster_id 5b2b31fe6b58b76236e580ca
# Copied all data for poster_id 59e0b13c20e88f68e8af29a0
# Copied all data for poster_id 5a898d2ce8ac2b3ae82f7ee7
# Copied all data for poster_id 55bd601267bc653fea5862da
# Copied all data for poster_id 5483c528d6e4a91b71c94320
# Copied all data for poster_id 595989005e87e7786f165159
# Copied all data for poster_id 5fc059d600000000010049cb
# Copied all data for poster_id 5945698250c4b465df6fac5d
# Copied all data for poster_id 5b8a337bba87a80001c85604
# Copied all data for poster_id 5e8986ca0000000001009a1c
# Copied all data for poster_id 5e8adbbd0000000001007864
# Copied all data for poster_id 5af3f7d6e8ac2b41762ac4ae
# Copied all data for poster_id 5fcf5784000000000101efc1
# Copied all data for poster_id 59db0933de5fb42c49530bc7
# Copied all data for poster_id 5c4d3b2f000000001000a286
# Copied all data for poster_id 59d3ec2120e88f31d24f18f4
# Copied all data for poster_id 5b138bc3e8ac2b3c8f189287
# Copied all data for poster_id 5de33a1500000000010052b4
# Copied all data for poster_id 595b673f82ec393761a1a5e2
# Copied all data for poster_id 5c9d62b30000000017027b59
# Copied all data for poster_id 569ba9c26a6a696bd4229774
# Copied all data for poster_id 565ac75482ec3922e2a6fac0
# Copied all data for poster_id 5ca2da7b000000001101356f
# Copied all data for poster_id 5b8926b4779bd5000102c4c9
# Copied all data for poster_id 5a8fa15111be1007987bf90f
# Copied all data for poster_id 5b27cebf11be105aaa9c3831
# Copied all data for poster_id 5adbe9894eacab2a75599cec
# Copied all data for poster_id 6037e6fb0000000001007b81
# Copied all data for poster_id 5fe7433e0000000001006fd0
# Copied all data for poster_id 5a7c6290e8ac2b1746864b8c
# Copied all data for poster_id 5ac648b24eacab4a8eed2227
# Copied all data for poster_id 58eaf1c382ec39578aaff0e1
# Copied all data for poster_id 5f4dde330000000001005ae2
# Copied all data for poster_id 5686b3b85e87e70e5dff2981
# Copied all data for poster_id 5ec39ebd0000000001002ece
# Copied all data for poster_id 595680a782ec3967f2ef39b3
# Copied all data for poster_id 5a94118f4eacab348019922b
# Copied all data for poster_id 59781e2982ec390928f591e2
# Copied all data for poster_id 565ea10ee00dd8533926b50b
# Copied all data for poster_id 57a17b2a50c4b462bc6b4e87
# Copied all data for poster_id 598429d46a6a692d9b05273c
# Copied all data for poster_id 5bd673117da0890001dc0b41
# Copied all data for poster_id 5b0916686b58b7203d315726
# Copied all data for poster_id 5aed3959e8ac2b2a1c881be3
# Copied all data for poster_id 5c9cb22d00000000110201ed
# Copied all data for poster_id 5a6068644eacab17a5cfde99
# Copied all data for poster_id 5c304a2e000000000501e21b
# Copied all data for poster_id 5a8f8cfd11be1077afeb8292
# Copied all data for poster_id 5a7bbc36b1da146656a9620b
# Copied all data for poster_id 5c8b33b0000000001101b2f8
# Copied all data for poster_id 5ad8811a4eacab1fe241579f
# Copied all data for poster_id 5af529c14eacab4dad70a133
# Copied all data for poster_id 5a52cc7111be1053a77bb537
# Copied all data for poster_id 5fb85207000000000100115f
# Copied all data for poster_id 5a93f34511be1078eb50eb23
# Copied all data for poster_id 562b89930bf90c096f8fc5a4
# Copied all data for poster_id 5d1db1b90000000011028188
# Copied all data for poster_id 596c819c50c4b477f9313941
# Copied all data for poster_id 56509e0d9eb5782270a7b5ea
# Copied all data for poster_id 595de0bc82ec39109baf8e0e
# Copied all data for poster_id 5a7e73fbe8ac2b0c12b500b1
# Copied all data for poster_id 53154482b4c4d64f5296aecd
# Copied all data for poster_id 5dc438f80000000001006568
# Copied all data for poster_id 55311e174fac633b88103ed4
# Copied all data for poster_id 54c63d02e7798957af1ce085
# Copied all data for poster_id 5f18e5bd00000000010006dd
# Copied all data for poster_id 5a329e5ce8ac2b0ba1fd2b29
# Copied all data for poster_id 5ca1ad86000000001702f940
# Copied all data for poster_id 5c183fdd000000000502f132
# Copied all data for poster_id 58e78fa182ec39414dc9d344
# Copied all data for poster_id 5eeb38e2000000000101f121
# Copied all data for poster_id 590e89be50c4b45e4ae66453
# Copied all data for poster_id 5a168ecc11be1037d2c3e342
# Copied all data for poster_id 59c7489944363b359bffb48c
# Copied all data for poster_id 56512b71f53ee0700dafb990
# Copied all data for poster_id 5cc1227e00000000100128b9
# Copied all data for poster_id 562ec0214476084b8a90e565
# Copied all data for poster_id 546c41e7d6e4a90ccff7dfc9
# Copied all data for poster_id 5d0f28350000000016023bc4
# Copied all data for poster_id 5b41b47111be103416daea65
# Copied all data for poster_id 5f5ef7be000000000101cedb
# Copied all data for poster_id 5c495d06000000001002f564
# Copied all data for poster_id 5d352890000000001200339c
# Copied all data for poster_id 58249fd56a6a695124d936b4
# Copied all data for poster_id 5edaebac000000000101e9de
# Copied all data for poster_id 58d0898582ec394f5b8e9afe
# Copied all data for poster_id 59eaf62b4eacab6f32f80076
# Copied all data for poster_id 56d05d244775a75237f74f39
# Copied all data for poster_id 5b34d8944eacab5f02e7c04b
# Copied all data for poster_id 604f1e5a0000000001006a6e
# Copied all data for poster_id 55179a1f2e1d9319168a90b8
# Copied all data for poster_id 55519d7cb203d93d4c2885ed
# Copied all data for poster_id 53dba221b4c4d659d329e9c1
# Copied all data for poster_id 5a02897fe8ac2b6e94f74da9
# Copied all data for poster_id 5b0e7acee8ac2b6d04d10ceb
# Copied all data for poster_id 5cd2f606000000001701c14b
# Copied all data for poster_id 56348e4d0bf90c56441188bb
# Copied all data for poster_id 5888b6fb5e87e771119b1830
# Copied all data for poster_id 58de75bf82ec3904983b1a15
# Copied all data for poster_id 564e76f40bf90c7d349960be
# Copied all data for poster_id 56e4327a1c07df26fc9bb08f
# Copied all data for poster_id 5a69eca311be10246f02b8a2
# Copied all data for poster_id 571ad34084edcd2024548fd4
# Copied all data for poster_id 56ba927750c4b478072c1e80
# Copied all data for poster_id 56591271e4251d32e78af3af
# Copied all data for poster_id 5438a99fd6e4a959b0f528d0
# Copied all data for poster_id 58904a5a5e87e73c3a7131b2
# Copied all data for poster_id 559a00a7b7ba22339829f6c2
# Copied all data for poster_id 56c5d4b784edcd0f6861660f
# Copied all data for poster_id 55bcd903f5a2636a0a837cac
# Copied all data for poster_id 5658676f6a6a691966fb692d
# Copied all data for poster_id 576ec2336a6a697c64af01d8
# Copied all data for poster_id 61f4c5a700000000100070b3
# Copied all data for poster_id 557385d567bc65400f3a52fd
# Copied all data for poster_id 57fc4b2c5e87e716836dc5b7
# Copied all data for poster_id 5b89358606311b000100174f
# Copied all data for poster_id 56062b6362a60c799e0a3137
# Copied all data for poster_id 5cb427010000000017018af8
# Copied all data for poster_id 5555f82862a60c1f3c591a01
# Copied all data for poster_id 5ed5bd8a000000000101e97f
# Copied all data for poster_id 5a1551ea4eacab5ed885da27
# Copied all data for poster_id 5a4751b5e8ac2b2fca285066
# Copied all data for poster_id 5fc237f3000000000100305b
# Copied all data for poster_id 6035e28c00000000010070af
# Copied all data for poster_id 5cff910c0000000012028a6d
# Copied all data for poster_id 557538fa3f0f3c4029df28f3
# Copied all data for poster_id 53d39b5bb4c4d6733971ae73
# Copied all data for poster_id 574c52706a6a695bfecd7cca
# Copied all data for poster_id 57a0cbe05e87e75371fcdb12
# Copied all data for poster_id 5dc550b20000000001004069
# Copied all data for poster_id 584cbbae50c4b445ab6eecfc
# Copied all data for poster_id 54f12d17a46e9665caba4926
# Copied all data for poster_id 582db5c25e87e7642ffa7d68
# Copied all data for poster_id 59f7138611be1052301fd495
# Copied all data for poster_id 5a9d321d11be1020ca94e9c5
# Copied all data for poster_id 5c7a2a93000000001002f543
# Copied all data for poster_id 5af54677e8ac2b522ae644d4
# Copied all data for poster_id 5fbf55ac00000000010054ec
# Copied all data for poster_id 5ad2aa044eacab01784eb989
# Copied all data for poster_id 57b4421450c4b416b711f415
# Copied all data for poster_id 5a741a29e8ac2b746f5d157c
# Copied all data for poster_id 59da0da644363b5f9e412308
# Copied all data for poster_id 5a9967a611be103fe161e2a0
# Copied all data for poster_id 5afe7a7011be107517033719
# Copied all data for poster_id 54cc6461b4c4d615fa2c667f
# Copied all data for poster_id 55d53a13b7ba22174bf7575b
# Copied all data for poster_id 547ec052d6e4a9754caf9361
# Copied all data for poster_id 5e538fea0000000001006fe1
# Copied all data for poster_id 56278f6df53ee036c2de35c5
# Copied all data for poster_id 5b246fc711be101fa9f360f4
# Copied all data for poster_id 5b9c6dc498c11e0001564ecd
# Copied all data for poster_id 5f2a671000000000010071c8
# Copied all data for poster_id 5c0b2e5b000000000701349b
# Copied all data for poster_id 5fc9c5480000000001004b0e
# Copied all data for poster_id 5ba27b0eeac9cb00014d99f7
# Copied all data for poster_id 58899cfd5e87e72fe39b173a
# Copied all data for poster_id 60d02cfb000000000101ef1b
# Copied all data for poster_id 566e5924cb35fb4d283c25af
# Copied all data for poster_id 5d5a8e4600000000010036e3
# Copied all data for poster_id 56f9f8d71c07df6ef7a450e0
# Copied all data for poster_id 5a68596d11be106ad08061e0
# Copied all data for poster_id 601d48c2000000000101e66a
# Copied all data for poster_id 5b77dd0342053200019ad7dd
# Copied all data for poster_id 5992b70a6a6a69019761c35d
# Copied all data for poster_id 5813fc735e87e735e4be4fd9
# Copied all data for poster_id 5a434407e8ac2b08d2058535
# Copied all data for poster_id 5aa03970e8ac2b0ad6853316
# Copied all data for poster_id 5ac17ecf11be10047bcec4ea
# Copied all data for poster_id 57d6338350c4b45215e07419
# Copied all data for poster_id 5906ca906a6a6959eb438f9a
# Copied all data for poster_id 56dcd49084edcd4df0b366f9
# Copied all data for poster_id 5edf0499000000000101c07d
# Copied all data for poster_id 561fb4933f0f3c13aee2939d
# Copied all data for poster_id 578cd95382ec391fbc1d6104
# Copied all data for poster_id 5f685cfe0000000001007dcb
# Copied all data for poster_id 5827c9cc5e87e751308b6453
# Copied all data for poster_id 5ea677c400000000010089c0
# Copied all data for poster_id 575640d6a9b2ed3ea07f0626
# Copied all data for poster_id 594691d882ec390305d76f54
# Copied all data for poster_id 5dbd3d0f0000000001002b36
# Copied all data for poster_id 609377b9000000000101f26f
# Copied all data for poster_id 5ed4c56f000000000101eaac
# Copied all data for poster_id 5b7d219f4a29df0001bb5c9c
# Copied all data for poster_id 54a5eff32e1d9357cd3e00e4
# Copied all data for poster_id 562f8c8ef53ee026a3c94b5e
# Copied all data for poster_id 5ac33e41e8ac2b4b04fa9106
# Copied all data for poster_id 5654b66ee58d1340bab82303
# Copied all data for poster_id 59d3950344363b57d08d95ad
# Copied all data for poster_id 59e69c37e8ac2b621bcd21a5
# Copied all data for poster_id 5c2f425b0000000007021828
# Copied all data for poster_id 57368f7382ec3909efa30c55
# Copied all data for poster_id 5763e7ee6a6a691228d3dc72
# Copied all data for poster_id 5aec1c2e6b58b77424eea1c3
# Copied all data for poster_id 569d129150c4b41ab8d40f19
# Copied all data for poster_id 5912c0c182ec392867212f48
# Copied all data for poster_id 579c1c1c82ec393b65bc5d30
# Copied all data for poster_id 5c808414000000001603be23
# Copied all data for poster_id 58c68a266a6a693afb0c8490
# Copied all data for poster_id 5f82ccf80000000001009829
# Copied all data for poster_id 5998e4664f8fd62f444368ae
# Copied all data for poster_id 5ebb75f3000000000101eb91
# Copied all data for poster_id 5e9f0e120000000001006f57
# Copied all data for poster_id 5cadb3f90000000011009529
# Copied all data for poster_id 5b5c91394eacab2dc2e4b67b
# Copied all data for poster_id 58776afc6a6a69429ae4d536
# Copied all data for poster_id 57b70b136a6a696401665f8d
# Copied all data for poster_id 543a03c4d6e4a9068205bed9
# Copied all data for poster_id 5e904e0f00000000010077e0
# Copied all data for poster_id 571fcdf91c07df7c143f4401
# Copied all data for poster_id 558f451cc2bdeb6632075d46
# Copied all data for poster_id 5caf11cc000000001600df32
# Copied all data for poster_id 5b77b08b6bd738000190f54b
# Copied all data for poster_id 5a14688c4eacab4360a4931b
# Copied all data for poster_id 5c7671bc0000000010016121
# Copied all data for poster_id 5edb16b40000000001007b8f
# Copied all data for poster_id 57ccd6d750c4b449065833f4
# Copied all data for poster_id 5e4ea0ef000000000100ac66
# Copied all data for poster_id 5a10d17ce8ac2b5cda5df3fb
# Copied all data for poster_id 5fc10298000000000101c68a
# Copied all data for poster_id 5d1980da0000000011028916
# Copied all data for poster_id 63d6321c00000000260064ee
# Copied all data for poster_id 5657d81c7c5bb814405de598
# Copied all data for poster_id 5e24184f000000000100012b
# Copied all data for poster_id 5bdd2f944e27cb00019df395
# Copied all data for poster_id 5e36ded60000000001003606
# Copied all data for poster_id 5fb0c739000000000101d469
# Copied all data for poster_id 599b0fb982ec393614c15016
# Copied all data for poster_id 56ca75b384edcd3659f7a8a3
# Copied all data for poster_id 5a80dcc611be10239545657e
# Copied all data for poster_id 5732bdf582ec390aff193608
# Copied all data for poster_id 5e5ca17e00000000010034c3
# Copied all data for poster_id 5a028c1011be1014ba3439ec
# Copied all data for poster_id 560a5dfee4b1cf350acf4433
# Copied all data for poster_id 59c87e5a44363b2cccb9dfc2
# Copied all data for poster_id 5bd90bb999715200013c8042
# Copied all data for poster_id 61a8914000000000210260d0
# Copied all data for poster_id 5b0fcfaf6b58b738ce05aa7b
# Copied all data for poster_id 5b4f6aa2e8ac2b2bd77ad3f6
# Copied all data for poster_id 5bc9d2fa636c170001715db8
# Copied all data for poster_id 5912ffa382ec39125e212f7c
# Copied all data for poster_id 5c07faa00000000007016613
# Copied all data for poster_id 5a60247b4eacab09e5e38bdb
# Copied all data for poster_id 5a7f295311be105c211222e5
# Copied all data for poster_id 5b59b8894eacab38a660741c
# Copied all data for poster_id 5a64aab811be106cfd490ce1
# Copied all data for poster_id 5bc15ffb208fe80001ea9ed8
# Copied all data for poster_id 5a6498404eacab66660e3c60
# Copied all data for poster_id 5ab6ac3d4eacab775c3ee894
# Copied all data for poster_id 5dbd413a00000000010098af
# Copied all data for poster_id 5a89825211be103171dd4924
# Copied all data for poster_id 5970495050c4b440fab52a1e
# Copied all data for poster_id 569bb3e4b8c8b458bd18c0b7
# Copied all data for poster_id 5fb5d6cb000000000100a365
# Copied all data for poster_id 56e771671c07df425877e731
# Data selection completed.

# %% [markdown]
# Count the number of poster_id directories in the all_data or test/data folder:

# %%
import os

# Define the path to the all_data folder
# all_data_folder = '/home/disk1/red_disk1/all_data'
all_data_folder = '/home/disk1/red_disk1/test/data'

# Get a list of all items in the all_data folder
all_items = os.listdir(all_data_folder)

# Filter the list to include only directories (which represent poster_id)
poster_ids = [item for item in all_items if os.path.isdir(os.path.join(all_data_folder, item))]

# Count the number of poster_id directories
num_poster_ids = len(poster_ids)

# Initialize a set to store unique post_ids
unique_post_ids = set()

# Iterate through each poster_id directory to count distinct post_id files
for poster_id in poster_ids:
    poster_id_path = os.path.join(all_data_folder, poster_id)
    post_files = os.listdir(poster_id_path)
    for post_file in post_files:
        post_id, _ = os.path.splitext(post_file)  # Extract post_id without file extension
        unique_post_ids.add(post_id)

# Count the number of distinct post_ids
num_post_ids = len(unique_post_ids)

# Print the results
print(f"There are {num_poster_ids} poster_id directories in the test/data folder.")
print(f"There are {num_post_ids} distinct post_id files in the test/data folder.")
# Out:
# There are 289 poster_id directories in the test/data folder.
# There are 34479 distinct post_id files in the test/data folder.
